# %% [markdown]
# ### Carregando arquivos:

# %%
import pandas as pd

train_df  = pd.read_csv("../../data/raw/train.csv")
unique_m_df = pd.read_csv("../../data/raw/unique_m.csv")

# %% [markdown]
# ### Features escolhidas:

# %%
lista_features = [
    'critical_temp',
    'number_of_elements',
    'wtd_entropy_atomic_mass',
    'range_fie',
    'range_atomic_radius',
    'entropy_Density',
    'entropy_ElectronAffinity',
    'wtd_entropy_FusionHeat',
    'wtd_std_ThermalConductivity',
    'entropy_Valence'
]

lista_features_array = []

# %% [markdown]
# ### Funções de plot:

# %%
def plot_original(feature_array, feature):

    # Histograma (original)
    axes[0].hist(feature_array, bins=50, edgecolor='black', alpha=0.7)
    axes[0].set_title(f'Histograma - Original: {feature}', fontsize=12, fontweight='bold')
    axes[0].set_xlabel('Valor')
    axes[0].set_ylabel('Frequência')

    # Boxplot (original)
    axes[1].boxplot(feature_array, vert=False)
    axes[1].set_title(f'Boxplot - Original: {feature}', fontsize=12, fontweight='bold')
    axes[1].set_xlabel('Valor')
    axes[1].set_yticks([])

def plot_tratado(feature_array, feature):

    # Histograma (tratado)
    axes[2].hist(crit_temp_array, bins=50, edgecolor='black', alpha=0.7)
    axes[2].set_title(f'Histograma - Tratado: {feature}', fontsize=12, fontweight='bold')
    axes[2].set_xlabel('Valor')
    axes[2].set_ylabel('Frequência')

    # Boxplot (tratado)
    axes[3].boxplot(crit_temp_array, vert=False)
    axes[3].set_title(f'Boxplot - Tratado: {feature}', fontsize=12, fontweight='bold')
    axes[3].set_xlabel('Valor')
    axes[3].set_yticks([])

# %% [markdown]
# ### Tratamento de features:

# %% [markdown]
# #### Carregando Dependências:

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle

# %% [markdown]
# #### Temperatura Crítica:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Temperatura Crítica"

# Formato array:
crit_temp_array = np.array(train_df[lista_features[0]])
plot_original(crit_temp_array, feature)

# Tratamento
crit_temp_array = np.sqrt(crit_temp_array)
plot_tratado(crit_temp_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/critic_temp.pkl', 'wb') as f:
    pickle.dump(crit_temp_array, f)

# %% [markdown]
# #### Número de Elementos:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Número de Elementos"

# Formato array:
n_element_array = np.array(train_df[lista_features[1]])
plot_original(n_element_array, feature)

# Tratamento
n_element_array = np.sqrt(n_element_array)
plot_tratado(n_element_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/n_element.pkl', 'wb') as f:
    pickle.dump(n_element_array, f)

# %% [markdown]
# #### Massa Atômica:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Massa Atômica"

# Formato array:
atomic_mass_array = np.array(train_df[lista_features[2]])
plot_original(atomic_mass_array, feature)

# Tratamento
atomic_mass_array = np.sqrt(atomic_mass_array)
plot_tratado(atomic_mass_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/atomic_mass.pkl', 'wb') as f:
    pickle.dump(atomic_mass_array, f)

# %% [markdown]
# #### Primeira Energia de Ionização:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Energia de Ionização"

# Formato array:
fie_array = np.array(train_df[lista_features[3]])
plot_original(fie_array, feature)

# Tratamento
fie_array = np.sqrt(fie_array)
plot_tratado(fie_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/fie.pkl', 'wb') as f:
    pickle.dump(fie_array, f)

# %% [markdown]
# #### Raio Atômico:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Raio Atômico"

# Formato array:
atom_radius_array = np.array(train_df[lista_features[4]])
plot_original(atom_radius_array, feature)

# Tratamento
atom_radius_array = np.sqrt(atom_radius_array)
plot_tratado(atom_radius_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/atom_radius.pkl', 'wb') as f:
    pickle.dump(atom_radius_array, f)

# %% [markdown]
# #### Densidade Atômica:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Densidade Atômica"

# Formato array:
density_array = np.array(train_df[lista_features[5]])
plot_original(density_array, feature)

# Tratamento
density_array = np.sqrt(density_array)
plot_tratado(density_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/density.pkl', 'wb') as f:
    pickle.dump(density_array, f)

# %% [markdown]
# #### Afinidade Eletrônica:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Afinidade Eletrônica"

# Formato array:
elec_aff_array = np.array(train_df[lista_features[6]])
plot_original(elec_aff_array, feature)

# Tratamento
elec_aff_array = np.sqrt(elec_aff_array)
plot_tratado(elec_aff_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/elec_aff.pkl', 'wb') as f:
    pickle.dump(elec_aff_array, f)

# %% [markdown]
# #### Calor de Fusão:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Calor de Fusão"

# Formato array:
fusion_heat_array = np.array(train_df[lista_features[7]])
plot_original(fusion_heat_array, feature)

# Tratamento
fusion_heat_array = np.sqrt(fusion_heat_array)
plot_tratado(fusion_heat_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/fusion_heat.pkl', 'wb') as f:
    pickle.dump(fusion_heat_array, f)

# %% [markdown]
# #### Condutividade Térmica:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Condutividade Térmica"

# Formato array:
thermal_cond_array = np.array(train_df[lista_features[8]])
plot_original(thermal_cond_array, feature)

# Tratamento
thermal_cond_array = np.sqrt(thermal_cond_array)
plot_tratado(thermal_cond_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/thermal_cond.pkl', 'wb') as f:
    pickle.dump(thermal_cond_array, f)

# %% [markdown]
# #### Valência:

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
axes = axes.flatten()

feature = "Valência"

# Formato array:
valence_array = np.array(train_df[lista_features[9]])
plot_original(valence_array, feature)

# Tratamento
valence_array = np.sqrt(valence_array)
plot_tratado(valence_array, feature)

plt.tight_layout()
plt.show()

# Garante que a pasta existe
os.makedirs("features_tratadas", exist_ok=True)

# Salva a variável transformada
with open('features_tratadas/valence.pkl', 'wb') as f:
    pickle.dump(valence_array, f)
